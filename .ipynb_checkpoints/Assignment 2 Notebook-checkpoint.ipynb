# %%
"""
@author Rahul Gupta
"""

import string
import re
import tweepy
import json
import twitterClient

import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import opinion_lexicon

from colorama import Fore, Style
import pandas as pd
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = (10,7)
plt.style.use('seaborn')

# %%
class TwitterProcessing:
    def __init__(self, tokeniser, lStopwords):
        self.tokeniser = tokeniser
        self.lStopwords = lStopwords

    def process(self, text):
        text = text.lower()
        tokens = self.tokeniser.tokenize(text)
        tokensStripped = [tok.strip() for tok in tokens]
        regexDigit = re.compile("^\d+\s|\s\d+\s|\s\d+$")
        regexHttp = re.compile("^http")

        return [tok for tok in tokensStripped if tok not in self.lStopwords and
                regexDigit.match(tok) == None and regexHttp.match(tok) == None]

# %%
def computeSentiment(lTokens, setPosWords, setNegWords):
    posNum = len([tok for tok in lTokens if tok in setPosWords])
    negNum = len([tok for tok in lTokens if tok in setNegWords])
    return posNum - negNum

def countWordSentimentAnalysis(setPosWords, setNegWords, tweets, tweetProcessor):
    lSentiment = []
    for tweet in tweets:
        try:
            tweetText = tweet['text']
            tweetDate = tweet['created_at']

            lTokens = tweetProcessor.process(tweetText)
            sentiment = computeSentiment(lTokens, setPosWords, setNegWords)
            lSentiment.append([pd.to_datetime(tweetDate),tweetText, sentiment])
        except KeyError as e:
            pass

    return lSentiment

def vaderSentimentAnalysis(tweets, tweetProcessor):
    sentAnalyser = SentimentIntensityAnalyzer()
    lSentiment = []
    for tweet in tweets:
        try:
            tweetText = tweet['text']
            tweetDate = tweet['created_at']

            lTokens = tweetProcessor.process(tweetText)
            dSentimentScores = sentAnalyser.polarity_scores(" ".join(lTokens))
            lSentiment.append([pd.to_datetime(tweetDate), tweetText, dSentimentScores['compound']])

        except KeyError as e:
            pass
    return lSentiment

# %%
api = twitterClient.twitter_client()

tweets = []
query = 'streaming service OR streaming movies OR streaming series'
max_tweets = 500

file_name = 'sentiment_rawdata.json'
# append all tweet data to list
# for tweet in tweepy.Cursor(api.search, q=query, lang="en").items(max_tweets):
#     tweets.append(tweet._json)

# with open(file_name, 'w') as f:
#     json.dump(tweets, f)

# %% [markdown]
# Don't read the json file again and again

# %%
with open(file_name, 'r') as f:
    for line in f:
        tweets = json.loads(line)

# %%
tweetTokenizer = TweetTokenizer()
lPunct = list(string.punctuation)
lStopwords = stopwords.words('english') + lPunct + ['rt', 'via', '...', '…', '"', "'", '`']

tweetProcessor = TwitterProcessing(tweetTokenizer, lStopwords)

PosWords = opinion_lexicon.positive()
NegWords = opinion_lexicon.negative()

# %%
len(NegWords)
# Out:
# 4783

# %%
lSentiment = countWordSentimentAnalysis(PosWords, NegWords, tweets, tweetProcessor)
# lSentiment = vaderSentimentAnalysis(args.tweetsFile, args.print, tweetProcessor)

# %%
df = pd.DataFrame(lSentiment)
df.columns = ['Timestamp', 'text','Sentiment']
df.Sentiment.unique()
# Out:
# array([ 1, -1,  0, -2,  2,  5,  4,  3])

# %%
pd.value_counts(df['Sentiment'].values, sort=True, ascending=False).plot(kind='bar', color='#006699')
plt.xlabel('Word Count')
plt.ylabel('Words')
plt.title('Bar chart of Sentiment Value')
plt.legend().set_visible(False)

# %%
df
# Out:
#               Timestamp                                               text  \
# 110 2018-05-16 00:12:42  @CaseyBurke18 @LuciferonFOX Hate to break this...
# 28  2018-05-16 04:51:03  Live action Doom Patrol series coming to DC St...
# 125 2018-05-15 23:18:11  still preliminary and complex as Netflix rival...
# 197 2018-05-15 20:21:05  OFFICIAL: What's streaming and what's not for ...
# 439 2018-05-15 11:52:05  RT @NickDerington: They're doing it! Doom Patr...
# 449 2018-05-15 11:28:43  RT @JonWithTheFace: DSTV: Hasn't changed their...
# 443 2018-05-15 11:41:09  How the hell can that be it!? #SaveLucifier  #...
# 436 2018-05-15 12:00:12  'Doom Patrol' Series Coming to DC Universe Str...
# 186 2018-05-15 20:36:19  RT @IGN: A Doom Patrol series is coming to the...
# 433 2018-05-15 12:04:51  No surprise since Teen Titans and Doom Patrol ...
# 191 2018-05-15 20:31:48  RT @IGN: A Doom Patrol series is coming to the...
# 428 2018-05-15 12:22:34  @deadmattergame Been anxiously waiting for you...
# 212 2018-05-15 19:35:01  RT @eStream_Studios: Doom Patrol Series Coming...
# 452 2018-05-15 11:14:57  RT @JonWithTheFace: DSTV: Hasn't changed their...
# 216 2018-05-15 19:29:52  RT @SuperBroMovies: CYBORG Will Play A Role In...
# 218 2018-05-15 19:24:10  ‘Doom Patrol’ Series Lands on DC Universe Stre...
# 220 2018-05-15 19:22:33  It’s a little sad that the #Tremors franchise ...
# 222 2018-05-15 19:15:02  RT @JonWithTheFace: DSTV: Hasn't changed their...
# 420 2018-05-15 12:43:25  ICYMI Doom Patrol TV series is joining the DC ...
# 224 2018-05-15 19:07:19  RT @JonWithTheFace: DSTV: Hasn't changed their...
# 227 2018-05-15 18:56:38  RT @JonWithTheFace: DSTV: Hasn't changed their...
# 228 2018-05-15 18:46:42  Watch this exclusive clip from the series 'Rou...
# 201 2018-05-15 20:00:32  RT @NickDerington: They're doing it! Doom Patr...
# 453 2018-05-15 11:07:47  RT @JonWithTheFace: DSTV: Hasn't changed their...
# 161 2018-05-15 21:23:55  @ShaneMBailey @RossADillon @AJ_ShopTalk @Curro...
# 456 2018-05-15 10:50:30  RT @IGN: A Doom Patrol series is coming to the...
# 468 2018-05-15 09:56:08  RT @NickDerington: They're doing it! Doom Patr...
# 108 2018-05-16 00:16:23  RT @HarleyMovieNews: BREAKING: Margot Robbie w...
# 115 2018-05-15 23:54:32  RT @PrimeVideo: #DawsonsCreek ended 15 years a...
# 119 2018-05-15 23:36:17  RT @NickDerington: They're doing it! Doom Patr...
# ..                  ...                                                ...
# 497 2018-05-15 08:03:50  RT @ninjaasleeper: #KYYOnVoot #KYYOnVoot Defin...
# 496 2018-05-15 08:04:38  Super excited to announce I’m starting a new l...
# 479 2018-05-15 09:30:37  The most popular love series is now streaming ...
# 477 2018-05-15 09:38:20  RT @jaydiwaniya: The most popular love series ...
# 482 2018-05-15 09:23:46  Truly this is a brilliant love series to watch...
# 478 2018-05-15 09:36:11  RT @jaydiwaniya: The most popular love series ...
# 499 2018-05-15 07:57:03  #KYYOnVoot #KYYOnVoot Definitely it won't get ...
# 92  2018-05-16 01:08:21  @TeamEveMyles Just finished “Keeping Faith”.  ...
# 396 2018-05-15 13:54:08  The advice that I get from larger streamers ha...
# 498 2018-05-15 08:00:18  RT @ninjaasleeper: #KYYOnVoot #KYYOnVoot Defin...
# 72  2018-05-16 02:12:54  When you are looking for shows to #bingewatch ...
# 162 2018-05-15 21:17:34  Hey, attention all Miyazaki fans! His feature ...
# 199 2018-05-15 20:17:29  Cobra Kai, which pays homage to 1980s series T...
# 157 2018-05-15 21:51:23  Imagine if we had all of the talented actors, ...
# 109 2018-05-16 00:12:46  @Hegelbon When you finally do streaming I thin...
# 159 2018-05-15 21:33:02  RT @ConnorAlexander: Let's get a #SaveTheExpan...
# 244 2018-05-15 18:06:16  Love seeing dual pc streaming setup, and some ...
# 337 2018-05-15 15:15:25  What are you doing now to ensure that your 201...
# 295 2018-05-15 16:22:39  Veerle Baetens is absolutely one of my top 3 f...
# 193 2018-05-15 20:23:22  RT @Length_hs: THX @uegliga for streaming me t...
# 195 2018-05-15 20:22:51  THX @uegliga for streaming me today. Pretty ni...
# 417 2018-05-15 13:01:14  RT @ManaByte: Disney is going to want a Marvel...
# 150 2018-05-15 22:08:04  RT @ManaByte: Disney is going to want a Marvel...
# 399 2018-05-15 13:45:57  RT @ManaByte: Disney is going to want a Marvel...
# 429 2018-05-15 12:19:46  RT @ManaByte: Disney is going to want a Marvel...
# 305 2018-05-15 16:07:11  RT @ManaByte: Disney is going to want a Marvel...
# 177 2018-05-15 20:40:30  RT @ManaByte: Disney is going to want a Marvel...
# 424 2018-05-15 12:31:33  RT @ManaByte: Disney is going to want a Marvel...
# 160 2018-05-15 21:25:43  RT @ManaByte: Disney is going to want a Marvel...
# 133 2018-05-15 22:55:20  How are you a work in progress?\n\n'Work In Pr...
#
#      Sentiment
# 110         -2
# 28          -2
# 125         -2
# 197         -2
# 439         -1
# 449         -1
# 443         -1
# 436         -1
# 186         -1
# 433         -1
# 191         -1
# 428         -1
# 212         -1
# 452         -1
# 216         -1
# 218         -1
# 220         -1
# 222         -1
# 420         -1
# 224         -1
# 227         -1
# 228         -1
# 201         -1
# 453         -1
# 161         -1
# 456         -1
# 468         -1
# 108         -1
# 115         -1
# 119         -1
# ..         ...
# 497          2
# 496          2
# 479          2
# 477          2
# 482          2
# 478          2
# 499          2
# 92           2
# 396          2
# 498          2
# 72           2
# 162          2
# 199          2
# 157          2
# 109          2
# 159          2
# 244          3
# 337          3
# 295          3
# 193          3
# 195          3
# 417          4
# 150          4
# 399          4
# 429          4
# 305          4
# 177          4
# 424          4
# 160          4
# 133          5
#
# [500 rows x 3 columns]

# %%
import tweepy
import pandas as pd
import nltk
import string
from nltk.sentiment.util import *
from nltk.corpus import opinion_lexicon
from nltk.tokenize import treebank

import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
plt.style.use('default')

# %% [markdown]
# ## Create API and authenticate

# %%
def get_twitter_api():
    consumer_key = "q3jskpUCOy2h64TgLIJVk4lYG"
    consumer_secret = "ihKjoH66jRlTypi5oFSye5exKnNyxpbLJREd5kf5ivrqBq9YjA"
    access_token = "36773543-oNFUjf69C58EKhCBNoeWHUVTrHHAKnmtCCvJBeD9D"
    access_secret = "u8milltoVvrRPAEl05TC70PbCuFiV8FH0g2t1BkUFD0a5"

    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)

    api = tweepy.API(auth)
    return api

# %% [markdown]
# ## Retrieve Tweets

# %%
# Get tweets
api = get_twitter_api()

# create list to append tweets to
tweets = []

query = 'streaming service OR streaming movies OR streaming series'
max_tweets = 500

# append all tweet data to list
for tweet in tweepy.Cursor(api.search, q=query, lang="en").items(max_tweets):
    tweets.append(tweet._json)

# %%
# convert 'tweets' list to pandas.DataFrame
tweets_df = pd.DataFrame(vars(tweets[i]) for i in range(len(tweets)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-8d658e20e8a1> in <module>()
#       1 # convert 'tweets' list to pandas.DataFrame
# ----> 2 tweets_df = pd.DataFrame(vars(tweets[i]) for i in range(len(tweets)))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     362         elif isinstance(data, (list, types.GeneratorType)):
#     363             if isinstance(data, types.GeneratorType):
# --> 364                 data = list(data)
#     365             if len(data) > 0:
#     366                 if is_list_like(data[0]) and getattr(data[0], 'ndim', 1) == 1:
#
# <ipython-input-4-8d658e20e8a1> in <genexpr>(.0)
#       1 # convert 'tweets' list to pandas.DataFrame
# ----> 2 tweets_df = pd.DataFrame(vars(tweets[i]) for i in range(len(tweets)))
#
# ...

# %%
print(tweets[0]['text'])
# Out:
# RT @exo_schedules: DAILY SCHEDULE 🗓 180510 | 10th May | #엑소 #EXO #CBX Schedule
#
# 💻 Netflix series [#SEHUN]
# 🎤 Concert + Meet &amp; Greet [#CBX_Ma…

# %%
[tweets[i]['text'] for i in range(len(tweets)-1)]
# Out:
# ['RT @exo_schedules: DAILY SCHEDULE 🗓 180510 | 10th May | #엑소 #EXO #CBX Schedule\n\n💻 Netflix series [#SEHUN]\n🎤 Concert + Meet &amp; Greet [#CBX_Ma…',
#  'RT @WE_ARE_THE_BORT: I have never seen a better adaptation of a written work than #TheExpanse series that SyFy just cancelled. It deserves…',
#  'Jon Favreau’s Star Wars series will be set between Return of the Jedi and The Force Awakens https://t.co/QO6OaTEuZ3 via @Verge',
#  "RT @silentmalware: @AmazonStudios  #SaveTheExpanse it's  fantastic science fiction with great actors, writers an incredible book series and…",
#  'RT @WE_ARE_THE_BORT: I have never seen a better adaptation of a written work than #TheExpanse series that SyFy just cancelled. It deserves…',
#  'RT @exo_schedules: DAILY SCHEDULE 🗓 180504 | 4th May | #엑소 #EXO Schedule\n\n🎉 Youth Day festival [#LAY]\n💻 Netflix series [#SEHUN]\n📺 TV Appear…',
# ...

# %%
# Export tweets
tweets_df.to_csv('tesla_tweets.csv')

# %%
tesla = pd.read_csv('tesla_tweets.csv')
tesla = tesla[tesla.lang=='en']
len(tesla.index)
# Out:
# 51

# %%
# Text pre processing
tweetTokeniser = nltk.tokenize.TweetTokenizer()
lPunct = list(string.punctuation)
lStopwords = nltk.corpus.stopwords.words('english') + lPunct + ['rt', 'via', '...']
tweetStemmer = nltk.stem.PorterStemmer()

def processTweet(text, tokenizer, stemmer, stopwords):
    text = text.lower()
    lTokens = tokenizer.tokenize(text)
    lStemmedTokens = set([stemmer.stem(tok) for tok in lTokens])
    return [tok for tok in lStemmedTokens if tok not in stopwords and not tok.isdigit()]

# %%
tesla['tokens'] = tesla.apply(lambda x: processTweet(x['text'], tokenizer=tweetTokeniser, stemmer=tweetStemmer, stopwords=lStopwords), axis=1)

# %%
my_list = pd.DataFrame(tesla['tokens'].apply(pd.Series).stack())
my_list.columns = ['words']

my_list['words'] = my_list[my_list.words.str.contains(r"@|#|http|…|tesla|’", regex=True) == False]

freq = my_list.groupby(['words']).size().reset_index(name='counts')
freq.sort_values(['counts'], ascending=False, inplace=True)
freq = freq.head(20)

# %%
# Bar chart of word frequency
freq.plot(kind='barh',x='words',y='counts', color='#006699')
ax = plt.gca().invert_yaxis()
plt.xlabel('Word Count')
plt.ylabel('Words')
plt.title('Bar chart of word frequency')
plt.legend().set_visible(False)

# %%
# Bar chart of Hashtags count
my_list = pd.DataFrame(tesla['tokens'].apply(pd.Series).stack())
my_list.columns = ['words']
my_list['words'] = my_list[my_list.words.str.contains(r"#", regex=True)]
my_list['words'] = my_list[my_list.words.str.contains(r"tesla", regex=True)==False]

freq = my_list.groupby(['words']).size().reset_index(name='counts')
freq.sort_values(['counts'], ascending=False, inplace=True)
freq = freq.head(20)

freq.plot(kind='barh',x='words',y='counts', color='#006699')
ax = plt.gca().invert_yaxis()
plt.xlabel('Word Count')
plt.ylabel('Words')
plt.title('Bar chart of Hashtags count')
plt.legend().set_visible(False)

# %%
# Subset data
import copy
tweets= copy.deepcopy(tesla[['text','retweet_count','source']])
tweets.sort_values('retweet_count',inplace=True, ascending=False)
# tweets = tweets[tweets.retweet_count > 50]
tweets.drop_duplicates(['text'],'first',True)
tweets.head()
# Out:
#                                                  text  retweet_count  \
# 56  RT @MyFavsTrash: Netflix: “Are you still watch...          35536
# 67  RT @rymakes: Is....was this on purpose Netflix...          14387
# 38  RT @electroboyusa: Dear @GOP,\n\nYou can dish ...           5191
# 40  RT @jiyongal: Seungri doing a photoshoot for y...           1988
# 54  RT @Toure: Sarah Sanders: "I hope that [Michel...           1743
#
#                  source
# 56   Twitter for iPhone
# 67  Twitter for Android
# 38  Twitter for Android
# 40   Twitter Web Client
# 54   Twitter Web Client

# %%
# Sentiment Analysis
def sentimentAnalysis(sentence):
    tokenizer = treebank.TreebankWordTokenizer()
    pos_words = 0
    neg_words = 0
    tokenized_sent = [word.lower() for word in tokenizer.tokenize(sentence)]

    count = []

    for word in tokenized_sent:
        if word in opinion_lexicon.positive():
            pos_words += 1
        elif word in opinion_lexicon.negative():
            neg_words += 1
        else:
            pass

    if pos_words > neg_words:
        return('Positive')
    elif pos_words < neg_words:
        return('Negative')
    elif pos_words == neg_words:
        return('Neutral')

# %%
tweets['sentiment'] = tweets.apply(lambda x: sentimentAnalysis(x['text']), axis=1)

# %%
# Sample Data to show sentiments
tweets.head(10)
# Out:
#                                                  text  retweet_count  \
# 56  RT @MyFavsTrash: Netflix: “Are you still watch...          35536
# 67  RT @rymakes: Is....was this on purpose Netflix...          14387
# 38  RT @electroboyusa: Dear @GOP,\n\nYou can dish ...           5191
# 40  RT @jiyongal: Seungri doing a photoshoot for y...           1988
# 54  RT @Toure: Sarah Sanders: "I hope that [Michel...           1743
# 44  RT @EXOXOXOID: Please streaming 'Busted!' on N...           1372
# 79  RT @milkdoggie: ✨Queens ✨\n---\nwatching @aggr...           1345
# 22  RT @OverlordEXO: Did You Watch It On Netflix?\...            942
# 23  RT @sense8: Name a better starting 8. #Sense8F...            864
# 24  RT @coolghost101: The best Darth Vader scene e...            321
#
#                  source sentiment
# 56   Twitter for iPhone   Neutral
# 67  Twitter for Android   Neutral
# 38  Twitter for Android  Negative
# 40   Twitter Web Client   Neutral
# ...

# %%
#Percentage distribution of Tesla Sentiments
freq = tweets.groupby('sentiment').size().reset_index(name='counts')
freq.sort_values(['counts'], ascending=False, inplace=True)
freq['perc']= freq['counts']/freq['counts'].sum() * 100

freq.plot(kind='bar',x='sentiment',y='perc', color='#006699')
plt.ylabel('Percentage')
plt.xlabel('')
plt.title('Percentage distribution of Tesla Sentiments')
plt.legend().set_visible(False)
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %%
#Percentage distribution of Tesla Sentiments
plt.figure(figsize=(12,8))
ax1 = plt.subplot(121, aspect='equal')
freq.plot(kind='pie',labels=freq.sentiment,y='perc', ax=ax1,autopct='%1.2f%%', 
 startangle=90, shadow=False, colors = ['#BBBBBB','#6baed6','#fb6a4a'])
plt.legend().set_visible(False)
plt.ylabel('')
plt.xlabel('')
plt.title('Percentage distribution of Tesla Sentiments')
# Out:
# Text(0.5,1,'Percentage distribution of Tesla Sentiments')

# %%
# Sentiment calculation polarity
analyzer=SentimentIntensityAnalyzer()
tweets['negative'] = tweets.apply(lambda x: analyzer.polarity_scores(x['text'])['neg'], axis=1)
tweets['neutral'] = tweets.apply(lambda x: analyzer.polarity_scores(x['text'])['neu'], axis=1)
tweets['positive'] = tweets.apply(lambda x: analyzer.polarity_scores(x['text'])['pos'], axis=1)
tweets['compound'] = tweets.apply(lambda x: analyzer.polarity_scores(x['text'])['compound'], axis=1)
tweets.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-24855c73a888> in <module>()
#       1 # Sentiment calculation polarity
# ----> 2 analyzer=SentimentIntensityAnalyzer()
#       3 tweets['negative'] = tweets.apply(lambda x: analyzer.polarity_scores(x['text'])['neg'], axis=1)
#       4 tweets['neutral'] = tweets.apply(lambda x: analyzer.polarity_scores(x['text'])['neu'], axis=1)
#       5 tweets['positive'] = tweets.apply(lambda x: analyzer.polarity_scores(x['text'])['pos'], axis=1)
#
# NameError: name 'SentimentIntensityAnalyzer' is not defined

# %%
# Top positive tweets
top = tweets.sort_values(['compound'], ascending=False)
top_tweets = top[['text','compound']].head(5)
top_tweets.to_csv('Top_positive.csv',index=False)

# Top Negative tweets
neg_tweets = top[['text','compound']].tail(5)
neg_tweets.to_csv('Top_negative.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'compound'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-4184e0d1f82a> in <module>()
#       1 # Top positive tweets
# ...

# %%
# Distribution of polarity
plt.style.use('ggplot')
plt.hist(tweets['compound'],color='#006699')
plt.title("Distribution of Polarity (Vader Approach)")
plt.xlabel("Value")
plt.ylabel("Frequency")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'compound'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-c2d8a852c7f2> in <module>()
#       1 # Distribution of polarity
# ...

# %%
#Tesla Tweet Sources
freq = tweets.groupby('source').size().reset_index(name='counts')
freq.sort_values(['counts'], ascending=False, inplace=True)
freq = freq.head(20)

freq.plot(kind='barh',x='source',y='counts', color='#006699')
plt.ylabel('Sources')
plt.xlabel('Count')
ax = plt.gca().invert_yaxis()
plt.title('Tesla Tweet Sources')
plt.legend().set_visible(False)
plt.xticks(rotation=0)
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30.]),
#  <a list of 7 Text xticklabel objects>)

# %%
def preProcessing(text, tokeniser, stopwords=[]):
    text = text.lower()
    tokens = tokeniser.tokenize(text)
    return [tok for tok in tokens if tok not in stopwords and not tok.isdigit()]

# %%
# Topic Modelling
tweetTokenizer = nltk.tokenize.TweetTokenizer()
punct = list(string.punctuation)
stopwordList = nltk.corpus.stopwords.words('english') + punct + ['rt', 'via', '...']

lTweets = []

# Initial Data Cleaning
for index, row in tweets.iterrows():
    lTokens = preProcessing(row['text'], tokeniser=tweetTokenizer, stopwords=lStopwords)
    lTweets.append(' '.join(lTokens))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Convert Features to vector
tfVectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=1200, stop_words='english')
tf = tfVectorizer.fit_transform(lTweets)

tfFeatureNames = tfVectorizer.get_feature_names()

# LDA Model
ldaModel = LatentDirichletAllocation(n_topics=10, max_iter=10, learning_method='online').fit(tf)

word_cloud = []
# Getting 10 topics
for topicId, lTopicDist in enumerate(ldaModel.components_):
#     print("Topic %d:" % (topicId))
    print(" ".join([tfFeatureNames[i] for i in lTopicDist.argsort()[:-10 - 1:-1]]))
    word_cloud.append(" ".join([tfFeatureNames[i] for i in lTopicDist.argsort()[:10]]))
# Out:
# recommend boys years really high like looks 범인은바로너 watching movies
# watch netflix pls like looks want good movies recommend today
# white watched 범인은바로너 seen like shrek got looks busted_sehun boys
# netflix need shows new really watch seen https watched good
# netflix boys got high shrek 범인은바로너 watching busted good best
# https netflix watching busted seen watch good 범인은바로너 years busted_sehun
# netflix want dear people white beautifully watched best punisher good
# want need https busted best punisher netflix premiosmtvmiaw watching good
# watch today like netflix boys looks good new 범인은바로너 watching
# watch netflix premiosmtvmiaw need mtvbrkpopexo busted_sehun recommend best years punisher
# /Users/rahul/anaconda3/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)

# %%
# Word cloud
from wordcloud import WordCloud

word_cloud_string = ''.join(map(str, word_cloud))
wordcloud = WordCloud().generate(str(tweets['text'][tweets['compound'] > 0]))
plt.figure(figsize=(16,12))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'compound'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-ce872152970b> in <module>()
#       3
# ...

# %%
# Model fitting
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import cross_validate
import numpy as np

vectorizer = TfidfVectorizer(stop_words=stopwordList,min_df=1,max_df=3,lowercase=True)


X = vectorizer.fit_transform(tweets['text'])

mlb = MultiLabelBinarizer()
y = mlb.fit_transform(tweets['sentiment'])

# here we can play with a number of different classifiers
# We have started with a SVM with a linear kernel
classifier = OneVsRestClassifier(LinearSVC())


lScoringMetric = ['precision_micro', 'recall_micro', 'f1_micro']
lScores = cross_validate(classifier, X, y=y,
                         cv=10,
                         scoring=lScoringMetric,
                         return_train_score=False)


# average F1 score
print("Average precision: " + str(np.mean(lScores['test_'+lScoringMetric[0]])))
print("Average recall: " + str(np.mean(lScores['test_' + lScoringMetric[1]])))
print("Average F1: " + str(np.mean(lScores['test_' + lScoringMetric[2]])))
# Out:
# Average precision: 0.6946137164543237
# Average recall: 0.6685714285714285
# Average F1: 0.6811231053686296
# /Users/rahul/anaconda3/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label 3 is present in all training examples.
#   str(classes[c]))
# /Users/rahul/anaconda3/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label 10 is present in all training examples.
#   str(classes[c]))
# /Users/rahul/anaconda3/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label 3 is present in all training examples.
#   str(classes[c]))
# /Users/rahul/anaconda3/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label 10 is present in all training examples.
#   str(classes[c]))
# /Users/rahul/anaconda3/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label 3 is present in all training examples.
#   str(classes[c]))
# ...
